# %%
from keras.models import load_model
from keras.utils import plot_model

model = load_model('models/lattice_points.model.keras')
plot_model(model, to_file='keras_model_diagram.png', show_shapes=True)
